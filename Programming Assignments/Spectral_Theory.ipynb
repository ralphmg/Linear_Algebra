# %% [markdown]
# \begin{align*}
# Assignment\, 1
# \end{align*}
#
# Source: https://www.kaggle.com/datasets/sujithmandala/obesity-classification-dataset

# %%
import pandas as pd
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

df=pd.read_csv(r'Obesity Classification.csv')
print(df.head())

selected_features = df[['ID','Age','Gender','Height','Weight','BMI','Label']]
selected_features = selected_features.apply(pd.to_numeric, errors='coerce').fillna(0)
scaler = StandardScaler()
selected_features_standardized = scaler.fit_transform(selected_features)

n_clusters = 3
spectral = SpectralClustering(n_clusters=n_clusters, random_state=42)
df['cluster'] = spectral.fit_predict(selected_features_standardized)

plt.scatter(selected_features_standardized[:, 0], selected_features_standardized[:, 1], c=df['cluster'], cmap='viridis')
plt.title('Age vs. BMI')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.colorbar(label='Cluster')
plt.show()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

df=pd.read_csv(r'Obesity Classification.csv')
print(df.head())

selected_features = df[['ID','Age','Gender','Height','Weight','BMI','Label']]
selected_features = selected_features.apply(pd.to_numeric, errors='coerce').fillna(0)
scaler = StandardScaler()
selected_features_standardized = scaler.fit_transform(selected_features)

n_clusters = 3
spectral = SpectralClustering(n_clusters=n_clusters, random_state=42)
df['cluster'] = spectral.fit_predict(selected_features_standardized)

plt.scatter(selected_features_standardized[:, 0], selected_features_standardized[:, 1], c=df['cluster'], cmap='viridis')
plt.title('Height vs. Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.colorbar(label='Cluster')
plt.show()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

df=pd.read_csv(r'Obesity Classification.csv')
print(df.head())

selected_features = df[['ID','Age','Gender','Height','Weight','BMI','Label']]
selected_features = selected_features.apply(pd.to_numeric, errors='coerce').fillna(0)
scaler = StandardScaler()
selected_features_standardized = scaler.fit_transform(selected_features)

n_clusters = 3
spectral = SpectralClustering(n_clusters=n_clusters, random_state=42)
df['cluster'] = spectral.fit_predict(selected_features_standardized)

plt.scatter(selected_features_standardized[:, 0], selected_features_standardized[:, 1], c=df['cluster'], cmap='viridis')
plt.title('Age vs. Weight')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.colorbar(label='Cluster')
plt.show()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

df=pd.read_csv(r'Obesity Classification.csv')
print(df.head())

selected_features = df[['ID','Age','Gender','Height','Weight','BMI','Label']]
selected_features = selected_features.apply(pd.to_numeric, errors='coerce').fillna(0)
scaler = StandardScaler()
selected_features_standardized = scaler.fit_transform(selected_features)

n_clusters = 3
spectral = SpectralClustering(n_clusters=n_clusters, random_state=42)
df['cluster'] = spectral.fit_predict(selected_features_standardized)

plt.scatter(selected_features_standardized[:, 0], selected_features_standardized[:, 1], c=df['cluster'], cmap='viridis')
plt.title('Height vs. BMI')
plt.xlabel('Height')
plt.ylabel('BMI')
plt.colorbar(label='Cluster')
plt.show()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# <b>Conclusion</b>:<br>
# Upon visual inspection of the scatter plots, it is apparent that the spectral clustering algorithm has grouped the data into three distinct clusters. Each scatter plot represents a different combination of features, providing insights into the relationships within the clusters. For instance, the scatter plot depicting Age vs. BMI and Height vs. Weight shows how the algorithm has identified patterns or similarities among individuals based on these features. The color-coded clusters in each plot highlight the algorithm's ability to separate data points into meaningful groups. However, further analysis, such as calculating silhouette scores for different cluster numbers, could offer a quantitative assessment of clustering quality. Additionally, domain expertise is essential for interpreting the significance of the identified clusters in the context of obesity classification. In conclusion, the spectral clustering algorithm has successfully partitioned the data into three clusters, revealing patterns and relationships among the selected features in the provided scatter plots.

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

G.add_edge("a", "b", weight=0.6)
G.add_edge("a", "c", weight=0.2)
G.add_edge("c", "d", weight=0.1)
G.add_edge("c", "e", weight=0.7)
G.add_edge("c", "f", weight=0.9)
G.add_edge("a", "d", weight=0.3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    G, pos, edgelist=esmall, width=6, alpha=0.5, edge_color="b", style="dashed"
)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels)

eigenvector_centrality = nx.eigenvector_centrality(G)
for node, centrality in eigenvector_centrality.items():
    print(f"{node}: {centrality}")

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# a: 0.51807347662071
# b: 0.21182192277183212
# c: 0.5986761070959697
# d: 0.4566010978754134
# e: 0.24477918831750853
# f: 0.24477918831750853

# %% [markdown]
# <br><br><br><br>
# \begin{align*}
# Assignment\, 2
# \end{align*}

# %%
import praw
import networkx as nx
import matplotlib.pyplot as plt

reddit = praw.Reddit(
    client_id = "EGjbvaHd6mn79lVqlDEOQQ",
    client_secret = "AIIwTDoDjifrtvTAYGQlHTjEqjpO2A",
    user_agent = "Far-Customer-7696",
)

def print_subreddit_info(subreddit):
    print(f"Subreddit: {subreddit.display_name}")
    print(f"Title: {subreddit.title}")

def get_top_post_id(subreddit):
    return subreddit.top(limit=1).__next__().id

def create_social_network(post_id):
    submission = reddit.submission(id=post_id)
    G = nx.Graph()

    for comment in submission.comments.list():
        if isinstance(comment, praw.models.MoreComments):
            continue

        if comment.author and comment.parent() and comment.parent().author:
            G.add_edge(comment.author, comment.parent().author)

    return G

def perform_social_network_analysis(social_network):
    eigenvector_centrality = nx.eigenvector_centrality(social_network)
    sorted_nodes = sorted(eigenvector_centrality, key=eigenvector_centrality.get, reverse=True)
    top_nodes = sorted_nodes[:5]
    print("Centrality Nodes based on corresponding Eigenvectors:", top_nodes)

def visualize_network(social_network):
    pos = nx.spring_layout(social_network)  
    nx.draw(social_network, pos, with_labels=True, font_size=8, font_color="black", alpha=0.7)
    plt.show()

subreddit_name = "health"
subreddit = reddit.subreddit(subreddit_name)

print_subreddit_info(subreddit)

post_id = get_top_post_id(subreddit)

social_network = create_social_network(post_id)

perform_social_network_analysis(social_network)

visualize_network(social_network)
# Out:
# Subreddit: health
# Title: Health
# Centrality Nodes based on corresponding Eigenvectors: [Redditor(name='VeganBoBegan'), Redditor(name='dr_chewman'), Redditor(name='bostonchef72296'), Redditor(name='Moist-Candy-6260'), Redditor(name='mardigrasking54')]

# %% [markdown]
# Hypothesis:<br>
# A myriad of users are actively engaging in conversations within the "health" subreddit, which greatly promotes user connectivity and participation in the subreddit.
#
# Conclusion:<br>
# The centrality nodes likely contribute to shaping the discourse and dynamics of the "health" community, inferring that these users play crucial roles in fostering engagement or providing valuable insights. The script's ability to extract meaningful information about influential contributors, coupled with the visual representation of the social network graph, enhances our understanding of the structure and interactions within the subreddit. Further analysis of the comments and activities of these central nodes could unveil specific themes or topics that are particularly impactful in the "health" community, contributing to a deeper understanding of the dynamics within this online forum.
